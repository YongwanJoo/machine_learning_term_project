# %%
from base import *  # Import predefined functions to maintain modularity
from sklearn.model_selection import train_test_split
import pandas as pd

# Load the dataset
data_path = 'ProcessedData.csv'
data = pd.read_csv(data_path, encoding='utf-8')

# Sample the data to reduce memory usage
sampled_data = sampling_data(data)
print("Sampled Data:")
print(sampled_data)
print('-----------------------------------------------------------')

# Split the sampled data into training and testing sets
train_data, test_data = train_test_split(sampled_data, test_size=0.2, random_state=42)
print("Train Data:")
print(train_data)
print('-----------------------------------------------------------')
print("Test Data:")
print(test_data)
print('-----------------------------------------------------------')

# Collaborative Filtering - Prepare User-Book Matrix
ratings = train_data[['User-ID', 'Title', 'Rating']]
user_book_matrix = ratings.pivot_table(index='User-ID', columns='Title', values='Rating').fillna(0)

# Select a test user and author
test_user_id = test_data['User-ID'].iloc[2]
test_author = test_data['Author'].iloc[2]

# Euclidean Distance Collaborative Filtering
print('Collaborative filtering result using Euclidean Distance:')
euclidean_recommendations_test = recommend_books_euclidean(user_book_matrix, user_id=test_user_id)
print("Recommendations (Euclidean Distance):")
for title in euclidean_recommendations_test:
    print(title)
print('-----------------------------------------------------------')

# Content-Based Filtering
print('Content-based filtering result:')
content_based_test = content_based_filtering(test_author, sampled_data)
print("Recommendations (Content-Based):")
for title in content_based_test:
    print(title)
print('-----------------------------------------------------------')

# Hybrid Filtering
def hybrid_filtering(author, user_id, processed_data, user_book_matrix, n_recommendations=5):
    """
    Combine results from Content-Based and Collaborative Filtering for hybrid recommendations.
    """
    # Get recommendations from content-based and collaborative methods
    content_based_recs = content_based_filtering(author, processed_data, n_recommendations)
    collaborative_recs = recommend_books_euclidean(user_book_matrix, user_id, n_recommendations)

    # Combine scores with weights
    content_based_weight = 0.5
    collaborative_weight = 0.5
    scores = {}

    for idx, book in enumerate(content_based_recs):
        scores[book] = scores.get(book, 0) + (n_recommendations - idx) * content_based_weight

    for idx, book in enumerate(collaborative_recs):
        scores[book] = scores.get(book, 0) + (n_recommendations - idx) * collaborative_weight

    # Sort by scores and return top recommendations
    ranked_books = sorted(scores.items(), key=lambda x: x[1], reverse=True)
    recommended_books = [book for book, _ in ranked_books[:n_recommendations]]

    return recommended_books

print('Hybrid filtering result:')
hybrid_filtering_test = hybrid_filtering(test_author, test_user_id, sampled_data, user_book_matrix)
print("Recommendations (Hybrid):")
for title in hybrid_filtering_test:
    print(title)
print('-----------------------------------------------------------')
# Out:
# Sampled Data:
#          User-ID        ISBN  Rating  \
# 1150      277427  002542730X      10
# 1168      277427  0061009059       9
# 1215      277427  0316776963       8
# 1235      277427  0345413903      10
# 1256      277427  0380702843       8
# ...          ...         ...     ...
# 1030970   276680  0452283205       7
# 1030997   276680  0743203631       7
# 1031009   276680  0743486226       6
# 1031034   276680  1573229083       7
# 1031042   276680  1931561648       9
#
#                                                      Title  \
# 1150     Politically Correct Bedtime Stories: Modern Ta...
# 1168     One for the Money (Stephanie Plum Novels (Pape...
# 1215                                Me Talk Pretty One Day
# 1235                                       The Murder Book
# 1256     The Return of the Indian (Indian in the Cupboard)
# ...                                                    ...
# 1030970                                     Falling Angels
# 1030997                 Gap Creek: The Story Of A Marriage
# 1031009                                    Angels & Demons
# 1031034                                    My Dream of You
# 1031042  The Time Traveler's Wife (Today Show Book Club...
#
#                      Author    Year                Publisher
# 1150      James Finn Garner  1994.0    John Wiley & Sons Inc
# 1168        Janet Evanovich  1995.0              HarperTorch
# 1215          David Sedaris  2001.0           Back Bay Books
# 1235     Jonathan Kellerman  2003.0         Ballantine Books
# 1256       Lynne Reid Banks  1999.0             HarperTrophy
# ...                     ...     ...                      ...
# 1030970     Tracy Chevalier  2002.0              Plume Books
# 1030997       Robert Morgan  2000.0               Touchstone
# 1031009           Dan Brown  2003.0                    Atria
# 1031034     Nuala O'Faolain  2002.0          Riverhead Books
# 1031042  Audrey Niffenegger  2003.0  MacAdam/Cage Publishing
#
# [30911 rows x 7 columns]
# -----------------------------------------------------------
# Train Data:
#         User-ID        ISBN  Rating  \
# 23554      6543  014025448X       8
# 879307   235935  0385722206       9
# 456679   123981  0440224764       7
# 89091     23768  0380718340       8
# 592504   160558  0451190521       7
# ...         ...         ...     ...
# 990887   265115  0671027662       8
# 156262    37950  0451190556       8
# 29627      8067  042518630X       2
# 502048   135149  0061098795       8
# 782108   211430  0767903382       8
#
#                                                     Title  \
# 23554              At Home in Mitford (The Mitford Years)
# 879307  Balzac and the Little Chinese Seamstress : A N...
# 456679                                        The Partner
# 89091   Cruel & Unusual (Kay Scarpetta Mysteries (Pape...
# 592504  The Green Mile: The Mouse on the Mile (Green M...
# ...                                                   ...
# 990887                                Coast Road: A Novel
# 156262  The Green Mile: The Bad Death of Eduard Delacr...
# 29627                                     Purity in Death
# 502048                                   The Wailing Wind
# 782108        Tender at the Bone: Growing Up at the Table
#
#                       Author    Year                 Publisher
# 23554              Jan Karon  1996.0              Viking Books
# 879307             DAI SIJIE  2002.0                    Anchor
# 456679          John Grisham  1998.0   Dell Publishing Company
# 89091   Patricia D. Cornwell  1994.0                      Avon
# 592504          Stephen King  1996.0               Signet Book
# ...                      ...     ...                       ...
# 990887      Barbara Delinsky  1999.0              Pocket Books
# 156262          Stephen King  1996.0               Signet Book
# 29627              J.D. Robb  2002.0  Berkley Publishing Group
# 502048        Tony Hillerman  2003.0               HarperTorch
# 782108           Ruth Reichl  1999.0            Broadway Books
#
# [24728 rows x 7 columns]
# -----------------------------------------------------------
# Test Data:
#         User-ID        ISBN  Rating  \
# 165867    40889  1558745157       9
# 879403   235935  0553582135       9
# 138567    35857  0312278586       5
# 86362     22625  038533334X      10
# 568246   153662  038531292X       6
# ...         ...         ...     ...
# 305690    81492  0316096199       9
# 258723    69078  0679429220       8
# 532051   143253  0140374248       8
# 343611    93047  0380727501       8
# 820553   223501  0375719180       7
#
#                                                     Title           Author  \
# 165867  The Lost Boy: A Foster Child's Search for the ...      Dave Pelzer
# 879403                                       Final Target    Iris Johansen
# 138567                         The Nanny Diaries: A Novel  Emma McLaughlin
# 86362                                      Charming Billy  Alice McDermott
# 568246                                           The Gift   Danielle Steel
# ...                                                   ...              ...
# 305690                                   Lucky : A Memoir     Alice Sebold
# 258723  Midnight in the Garden of Good and Evil: A Sav...     John Berendt
# 532051                          James and the Giant Peach       Roald Dahl
# 343611                          Notes from a Small Island      Bill Bryson
# 820553            The Miracle Life of Edgar Mint: A Novel      Brady Udall
#
#           Year              Publisher
# 165867  1997.0  Health Communications
# 879403  2002.0           Bantam Books
# 138567  2002.0     St. Martin's Press
# 86362   1999.0                  Delta
# 568246  1994.0        Delacorte Press
# ...        ...                    ...
# 305690  2002.0         Back Bay Books
# 258723  1994.0           Random House
# 532051  2000.0    Penguin USA (Paper)
# 343611  1997.0              Perennial
# 820553  2002.0      Vintage Books USA
#
# [6183 rows x 7 columns]
# -----------------------------------------------------------
# Collaborative filtering result using Euclidean Distance:
# RMSE for Euclidean distance recommendations: 2.5249011798885053
# Recommendations (Euclidean Distance):
# Eragon (Inheritance, Book 1)
# Haunted
# Easy Prey
# 16 Lighthouse Road
# Term Limits
# -----------------------------------------------------------
# Content-based filtering result:
# Recommendations (Content-Based):
# Turtle Moon
# Blue Diary
# Turtle Moon
# Blue Diary
# Second Nature
# -----------------------------------------------------------
# Hybrid filtering result:
# RMSE for Euclidean distance recommendations: 2.5249011798885053
# Recommendations (Hybrid):
# Turtle Moon
# Blue Diary
# Eragon (Inheritance, Book 1)
# Haunted
# Easy Prey
# -----------------------------------------------------------
